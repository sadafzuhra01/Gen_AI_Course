# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\PMLS\\Desktop\\Gen_AI_Course\\1-Python\\1.8-File-Handling'

# %%
path = "package"
os.mkdir(path)

# %%
items = os.listdir()
print(items)
# Out:
# ['1.8.1-file-operations.ipynb', '1.8.2-File-Paths.ipynb', 'example.txt', 'package']
