# %%
## OOP - Object Oriented programming
## classes: attributes/instance variables, methods

# %%
class Car:
    pass

audi = Car()


print(type(Car))
print(type(audi))
# Out:
# <class 'type'>
# <class '__main__.Car'>

# %%
## Attributes / Instance Variables

class Dog:
    def __init__(self, name, age):
        self.name= name
        self.age = age 


dog1 = Dog('Tomy',3)

print(dog1.age)
print(dog1.name)
# Out:
# 3
# Tomy

# %%
dog2 = Dog('Lucy', 2.5)
dog3 = Dog('stark', 4)

print(dog2.age)
print(dog3.name)
# Out:
# 2.5
# stark

# %%
## Methods 
class Dog:
    def __init__(self, name, age):
        self.name= name
        self.age = age 

    
    def bark(self):
        print(f'{self.name}, says woof!')

# %%
dog4 = Dog('Jacki', 3)

dog4.bark()
# Out:
# Jacki, says woof!

# %%
## Bank Account

class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} has been submiited and the Current balance is {self.balance}.")

    def withdraw(self, amount):
        self.balance -= amount
        print(f"{amount} has been withdrawn, and the Current balance is {self.balance}")


    def check_balance(self):
        print(f"Current balance is {self.balance}")

# %%
acc1 = BankAccount('Haseeb Raza', 5000)

acc1.check_balance()
# Out:
# Current balance is 5000

# %%
acc1.deposit(1000)
# Out:
# 1000 has been submiited and the Current balance is 6000.

# %%
acc1.withdraw(3000)
# Out:
# 3000 has been withdrawn, and the Current balance is 3000
