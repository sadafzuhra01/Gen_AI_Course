# %%
## Basic Data Types in Python
## 1- Integers
## 2- Floats
## 3- Strings
## 4- Boolean
## Type Conversion
## Type Inferencing

# %%
age = 21

# %%
print(age)
print(type(age))
# Out:
# 21
# <class 'int'>

# %%
height = 21.0
print(height)
print(type(height))
# Out:
# 21.0
# <class 'float'>

# %%
gene_1 = "ATCGGGTAC"
print(gene_1)
print(type(gene_1))
# Out:
# ATCGGGTAC
# <class 'str'>

# %%
age = 21 
height = 5.7
print(age == height)
# Out:
# False

# %%
gene_2 = "ATTGCACG"
print(gene_1==gene_2)
# Out:
# False

# %%
print(type(False))
# Out:
# <class 'bool'>
