# %%
## Dictionaries in Python 
## Creating Dictionaries 
## Accessing Dictionaries 
## MOdifying the dictionary
## Dictionary Methods
## Iterating over Dictionaries
## Nested Dictionaries
## Iterating over Nested Dictionries
## Dictionary Comprehension
## Real-World
## Mongo-DB and Cassendra

# %%
## Creating a dictionary
dict = {}

print(type(dict))
# Out:
# <class 'dict'>

# %%
## creating dictionary with key-value pairs
## unordered collection of data, in the form key value pairs, where the key is 
## unique and immutable 
dict = {"name": "Haseeb", "age":21, "Education": "Microbiologist" }
print(dict)
print(type(dict))
# Out:
# {'name': 'Haseeb', 'age': 21, 'Education': 'Microbiologist'}
# <class 'dict'>

# %%
## Key: Immutable and Unique 
dict = {"name": "Haseeb", "age":21, "Education": "Microbiologist", "name":"Mubeen" }

print(dict)
# Out:
# {'name': 'Mubeen', 'age': 21, 'Education': 'Microbiologist'}

# %%
dict = {"Names": ["Haseeb","Mubeen","Sadia"], "Age":[21,25,24], "Qualification":["BS","MS","MS"] }

print(dict)
# Out:
# {'Names': ['Haseeb', 'Mubeen', 'Sadia'], 'Age': [21, 25, 24], 'Qualification': ['BS', 'MS', 'MS']}

# %%
## Accessing Dictionaries
print(dict["Names"][1])

print(dict["Age"][0])
# Out:
# Mubeen
# 21

# %%
## Modifying the Dictionary
dict["Names"][0]="Muntaha"

print(dict["Names"])
# Out:
# ['Muntaha', 'Mubeen', 'Sadia']

# %%
dict["Income"]=[100,300,50]

# %%
print(dict)
# Out:
# {'Names': ['Muntaha', 'Mubeen', 'Sadia'], 'Age': [21, 25, 24], 'Qualification': ['BS', 'MS', 'MS'], 'Income': [100, 300, 50]}

# %%
del dict["Income"]

print(dict)
# Out:
# {'Names': ['Muntaha', 'Mubeen', 'Sadia'], 'Age': [21, 25, 24], 'Qualification': ['BS', 'MS', 'MS']}

# %%
## Dictionary Methods

dict.get("Names")
# Out:
# ['Muntaha', 'Mubeen', 'Sadia']

# %%
print(dict.keys())
print(dict.values())
print(dict.items())
# Out:
# dict_keys(['Names', 'Age', 'Qualification'])
# dict_values([['Muntaha', 'Mubeen', 'Sadia'], [21, 25, 24], ['BS', 'MS', 'MS']])
# dict_items([('Names', ['Muntaha', 'Mubeen', 'Sadia']), ('Age', [21, 25, 24]), ('Qualification', ['BS', 'MS', 'MS'])])

# %%
## Assignment

a=dict.popitem()

# %%
print(a)
# Out:
# ('Age', [21, 25, 24])

# %%
dict_2 = dict.copy()
print(dict_2)
# Out:
# {'Names': ['Muntaha', 'Mubeen', 'Sadia']}

# %%
dict = {"Names": ["Haseeb","Mubeen","Sadia"], "Age":[21,25,24], "Qualification":["BS","MS","MS"] }

# %%
dict_2 = dict.copy()
print(dict_2)
# Out:
# {'Names': ['Haseeb', 'Mubeen', 'Sadia'], 'Age': [21, 25, 24], 'Qualification': ['BS', 'MS', 'MS']}

# %%
a = dict.popitem()

print(dict_2)
# Out:
# {'Names': ['Haseeb', 'Mubeen', 'Sadia'], 'Age': [21, 25, 24], 'Qualification': ['BS', 'MS', 'MS']}

# %%
## Iterating over dictionaries

for key,value in dict.items():
    print(f"{key}: {value}")

for key in dict.keys():
    print(key)

for value in dict.values():
    print(value)
# Out:
# Names: ['Haseeb', 'Mubeen', 'Sadia']
# Age: [21, 25, 24]
# Names
# Age
# ['Haseeb', 'Mubeen', 'Sadia']
# [21, 25, 24]

# %%
print(dict)
# Out:
# {'Personal Details': {'Name': 'Haseeb', 'Age': 21, 'Email': 'haseebraza.hr13@gmail.com'}}

# %%
dict = {
    'Personal Details': {'Name': 'Haseeb', 'Age': 21, 'Email': 'haseebraza.hr13@gmail.com'},
    "Products": {"IT":"Laptops", "Grocery":"Water", "Clothings":"Gents"}
    }

print(type(dict))
# Out:
# <class 'dict'>

# %%
## Iterating over Nested Dictionary

for key,value in dict.items():
    for sub_key,sub_value in value.items():
         print(f"{sub_key}:{sub_value} ")
# Out:
# Name:Haseeb
# Age:21
# Email:haseebraza.hr13@gmail.com
# IT:Laptops
# Grocery:Water
# Clothings:Gents

# %%
## Dictionary Comprehension

## {expression for item in iterable if condition}

square_dict = {x: x**2 for x in range(10) if x%2==0}

print(square_dict)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
## Real-World Examples

## Letter Frequency

letters = ['a','b','c','d','a','a','c','c','d', 'b','b','d']

frequency={}

for letter in letters:
    if letter in frequency:
        frequency[letter] += 1
    else:
        frequency[letter] = 1

print(frequency)
# Out:
# {'a': 3, 'b': 3, 'c': 3, 'd': 3}
